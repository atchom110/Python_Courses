# %%
import pandas as pd
import numpy as np

phone_list=pd.read_excel("PhoneNumber_1.xlsx", sheet_name=["Kiroukou","MSF","Gawar"])
# Out:
# C:\Users\UNHCR CMRMA ENREG\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\UNHCR CMRMA ENREG\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\UNHCR CMRMA ENREG\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
phone_list.keys()
# Out:
# dict_keys(['Kiroukou', 'MSF', 'Gawar'])

# %%
phone_list['MSF'].head()
# Out:
#    # Registration Group ID       Full Name  Size  Age     Sex Telephone  \
# 0  1        417-23-1523192        Modu ALI     1   26    Male       NaN
# 1  2        417-23-1523448    Modu KALDAPA     1   23    Male       NaN
# 2  3        417-23-1541051        Modu ALI     1   36    Male       NaN
# 3  4        417-23-1882757  Mohammed BUKAR     1   24    Male       NaN
# 4  5        417-23-1346545    Mariamu MODU     1   81  Female       NaN
#
#    Telephone2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
phone_msf=pd.read_excel("Tel_MSF.xlsx")

# %%
phone_msf.head()
# Out:
#   Registration Group  Phone Number 1:
# 0     417-23-1883202        652894749
# 1       417-19-05770        682820328
# 2       417-21-07045        653147669
# 3       417-19-05879        652995870
# 4       883-17H01417        673100319

# %%
# rename column name
phone_msf.rename(columns={'Phone Number 1:':'phone'}, inplace=True)

# %%
phone_msf.head(46)
# Out:
#    Registration Group       phone
# 0      417-23-1883202   652894749
# 1        417-19-05770   682820328
# 2        417-21-07045   653147669
# 3        417-19-05879   652995870
# 4        883-17H01417   673100319
# 5        BEF-23-00455   671008905
# 6      417-23-2598260   651909101
# 7        417-19-10752   670727293
# 8        417-22-30514   651282061
# 9        883-17HO1017   691072992
# 10       883-15H08710   699215382
# 11       BEF-23-00328   654187573
# 12       417-21-03032   653301594
# 13       417-20-01367   681268848
# 14       417-20-00235   651044565
# 15       417-22-18897   671109465
# 16     417-23-1344787   653123066
# 17       BEF-23-00740   671325626
# 18       417-22-00205   650453213
# 19       417-22-16268  6710256981
# 20       417-19-10172    65293018
# 21     417-23-1999901   651617021
# 22       417-21-07327   650403329
# 23       BEF-24-00123   653015926
# 24       BEF-24-00159   670239308
# 25       883-14H05405   682044795
# ...

# %%
# rename column name
phone_list['MSF'].rename(columns={'Telephone2':'call2'}, inplace=True)

# %%
# rename column name
phone_list['MSF'].rename(columns={'Registration Group ID':'Registration Group'}, inplace=True)

# %%
phone_list['MSF'].head()
# Out:
#    # Registration Group       Full Name  Size  Age     Sex Telephone  call2
# 0  1     417-23-1523192        Modu ALI     1   26    Male       NaN    NaN
# 1  2     417-23-1523448    Modu KALDAPA     1   23    Male       NaN    NaN
# 2  3     417-23-1541051        Modu ALI     1   36    Male       NaN    NaN
# 3  4     417-23-1882757  Mohammed BUKAR     1   24    Male       NaN    NaN
# 4  5     417-23-1346545    Mariamu MODU     1   81  Female       NaN    NaN

# %%
right_join=phone_list['MSF'].merge(phone_msf,on='Registration Group',how='right')

# %%
right_join.head(60)
# Out:
#          # Registration Group               Full Name  Size   Age     Sex  \
# 0   5372.0     417-23-1883202             Fatima MODU   5.0  41.0  Female
# 1   7340.0       417-19-05770  MallumAmbadi ABBU AMMA   5.0  62.0    Male
# 2   5673.0       417-21-07045           Fatima YUSUFA   5.0  33.0  Female
# 3   2264.0       417-19-05879            Falmata MODU   3.0  30.0  Female
# 4   6071.0       883-17H01417         Halima MUSTAPHA   5.0  27.0  Female
# 5   7414.0       BEF-23-00455              Aisha MODU   5.0  31.0  Female
# 6   1078.0     417-23-2598260              Fatima ALI   3.0  39.0  Female
# 7   4997.0       417-19-10752                Hawa ALI   4.0  35.0  Female
# 8   4998.0       417-22-30514              Bintu MODU   4.0  32.0  Female
# 9      NaN       883-17HO1017                     NaN   NaN   NaN     NaN
# 10  3156.0       883-15H08710             Abukar UMAR   4.0  31.0    Male
# 11  5115.0       BEF-23-00328               Hawa ADJI   4.0  46.0  Female
# ...

# %%
new_columns=['#','Registration Group','Full Name','Size','Age','Sex','Telephone','phone','call2']
right_join=right_join[new_columns]

# %%
right_join
# Out:
#          # Registration Group       Full Name  Size  Age     Sex  \
# 0        1     417-23-1523192        Modu ALI     1   26    Male
# 1        2     417-23-1523448    Modu KALDAPA     1   23    Male
# 2        3     417-23-1541051        Modu ALI     1   36    Male
# 3        4     417-23-1882757  Mohammed BUKAR     1   24    Male
# 4        5     417-23-1346545    Mariamu MODU     1   81  Female
# ...    ...                ...             ...   ...  ...     ...
# 7567  7568       417-19-01131       Izza MODU     5   40  Female
# 7568  7569       417-22-20099  Aisha MOHAMMED     5   27  Female
# 7569  7570       BEF-23-01216  Kellu MUSTAPHA     5   46  Female
# 7570  7571       BEF-23-01668   Fana MOHAMMED     5   46  Female
# 7571  7572       417-22-24114     Halima MODU     5   20  Female
#
#           Telephone  phone  call2
# 0               NaN    NaN    NaN
# 1               NaN    NaN    NaN
# 2               NaN    NaN    NaN
# 3               NaN    NaN    NaN
# ...

# %%
right_join.head(5376)
# Out:
#          # Registration Group          Full Name  Size  Age     Sex Telephone  \
# 0        1     417-23-1523192           Modu ALI     1   26    Male       NaN
# 1        2     417-23-1523448       Modu KALDAPA     1   23    Male       NaN
# 2        3     417-23-1541051           Modu ALI     1   36    Male       NaN
# 3        4     417-23-1882757     Mohammed BUKAR     1   24    Male       NaN
# 4        5     417-23-1346545       Mariamu MODU     1   81  Female       NaN
# ...    ...                ...                ...   ...  ...     ...       ...
# 5371  5372     417-23-1883202        Fatima MODU     5   41  Female       NaN
# 5372  5373     417-23-1999724  DangwaToma MAZEMI     5   55    Male       NaN
# 5373  5374       417-19-11200        Bintu BUKAR     5   37  Female       NaN
# 5374  5375       417-19-11249        Aisha UMARA     5   25  Female       NaN
# 5375  5376       417-19-11316     Gidaya PARDAPA     5   27    Male       NaN
#
#             phone  call2
# ...

# %%
#right_join['phone']=[x.astype(str).str(".0") for x in right_join['phone']]
right_join['phone'] = right_join['phone'].astype(str).str.lstrip('.0').str.rstrip('.0')

# %%
right_join.head(4998)
# Out:
#          # Registration Group         Full Name  Size  Age     Sex Telephone  \
# 0        1     417-23-1523192          Modu ALI     1   26    Male       NaN
# 1        2     417-23-1523448      Modu KALDAPA     1   23    Male       NaN
# 2        3     417-23-1541051          Modu ALI     1   36    Male       NaN
# 3        4     417-23-1882757    Mohammed BUKAR     1   24    Male       NaN
# 4        5     417-23-1346545      Mariamu MODU     1   81  Female       NaN
# ...    ...                ...               ...   ...  ...     ...       ...
# 4993  4994       417-22-19603    Vadzaya NGOLDA     4   30  Female       NaN
# 4994  4995       BEF-23-02032  Rukaiya ABUBAKAR     4   31  Female       NaN
# 4995  4996       BEF-24-00138       Abba JALAM      4   33  Female       NaN
# 4996  4997       417-19-10752          Hawa ALI     4   35  Female       NaN
# 4997  4998       417-22-30514        Bintu MODU     4   32  Female       NaN
#
#           phone  call2
# ...

# %%
right_join.to_excel("phone_list2024.xlsx")
