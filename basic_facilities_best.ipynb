# %%
import pandas as pd

df=pd.read_excel('BASIC_FACILITIES.xlsx')

# %%
df.head()
# Out:
#                     start                     end Date of Data Collection  \
# 0 2024-04-19 09:39:02.272 2024-04-19 09:40:41.868              2024-04-19
# 1 2024-04-19 09:40:46.635 2024-04-19 09:42:18.234              2024-04-19
# 2 2024-04-19 09:42:24.810 2024-04-19 09:44:54.180              2024-04-19
# 3 2024-04-19 11:36:41.390 2024-04-19 11:38:03.117              2024-04-19
# 4 2024-04-15 11:00:29.509 2024-04-15 11:07:49.653              2024-04-15
#
#   Innumerator Name:  Progres ID Code Individual_number:  \
# 0      Sunday AYUBA              NaN        883-0007610
# 1      Sunday AYUBA              NaN       883-00025272
# 2      Sunday AYUBA              NaN       883-00074248
# 3      Sunday AYUBA              NaN       883-00002544
# 4    Saleh mohammed              NaN       883-00055791
#
#   What is your Family Name and Given Name? Gender:  Age:  \
# 0                           Zara Mohammed   Female    63
# 1                           Esther Filibus  Female    49
# ...

# %%
df.columns
# Out:
# Index(['start', 'end', 'Date of Data Collection', 'Innumerator Name:',
#        'Progres ID Code', 'Individual_number:',
#        'What is your Family Name and Given Name?', 'Gender:', 'Age:',
#        'Do you have any specific needs?', 'Specific needs categories',
#        'Specific needs categories/Child at risk',
#        'Specific needs categories/Single parent',
#        'Specific needs categories/Unaccompanied or separated child',
#        'Specific needs categories/Older person at risk',
#        'Specific needs categories/Woman at risk',
#        'Specific needs categories/Disability',
#        'Specific needs categories/Serious medical condition',
#        'Specific needs categories/Family unity',
#        'Specific needs categories/Specific legal and physical protection needs',
#        'Specific needs categories/SGBV', 'Specific needs categories/Torture',
#        'Does your family have access to water?',
#        'Does your family have a shelter ?',
# ...

# %%
df.columns('Specific needs categories/Child at risk')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.columns('Specific needs categories/Child at risk')
#
# TypeError: 'Index' object is not callable

# %%
pd[pd.Specific needs categories/Child at risk.str.contains('Specific needs categories/Child at risk')]
# Out:
#   Cell In[11], line 1
#     pd[pd.Specific needs categories/Child at risk.str.contains('Specific needs categories/Child at risk')]
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.describe()
# Out:
#        Progres ID Code         Age:  Specific needs categories/Child at risk  \
# count              0.0   789.000000                               590.000000
# mean               NaN    42.220532                                 0.116949
# std                NaN    70.733912                                 0.321632
# min                NaN     5.000000                                 0.000000
# 25%                NaN    31.000000                                 0.000000
# 50%                NaN    38.000000                                 0.000000
# 75%                NaN    44.000000                                 0.000000
# max                NaN  1988.000000                                 1.000000
#
#        Specific needs categories/Single parent  \
# count                               590.000000
# mean                                  0.059322
# std                                   0.236427
# min                                   0.000000
# ...

# %%
df['Specific needs categories/Family unity'].value_counts()
# Out:
# 0.0    413
# 1.0    177
# Name: Specific needs categories/Family unity, dtype: int64

# %%
df['Specific needs categories/Woman at risk'].value_counts()
# Out:
# 0.0    484
# 1.0    106
# Name: Specific needs categories/Woman at risk, dtype: int64

# %%
#filt=df['Specific needs categories']
c1=df['Specific needs categories'].value_counts()
# Out:
# Family unity                                                                             171
# Woman at risk                                                                             84
# Unaccompanied or separated child                                                          77
# Child at risk                                                                             39
# Serious medical condition                                                                 30
# Disability                                                                                29
# Older person at risk                                                                      29
# SGBV                                                                                      28
# Single parent                                                                             27
# Torture                                                                                   13
# ...

# %%
pbs=df.groupby(['Specific needs categories'])

# %%
pbs.get_group('Family unity')
# Out:
#                       start                     end Date of Data Collection  \
# 5   2024-04-15 09:05:28.639 2024-04-15 12:35:17.629              2024-04-15
# 7   2024-04-15 10:55:23.364 2024-04-15 12:36:34.591              2024-04-15
# 13  2024-04-15 13:35:54.774 2024-04-15 13:46:06.176              2024-04-15
# 17  2024-04-15 10:02:15.578 2024-04-15 10:10:30.854              2024-04-15
# 26  2024-04-15 14:56:00.309 2024-04-15 14:58:42.200              2024-04-16
# ..                      ...                     ...                     ...
# 755 2024-04-19 11:49:09.608 2024-04-19 11:51:23.287              2024-04-19
# 758 2024-04-19 12:04:05.729 2024-04-19 12:06:24.524              2024-04-19
# 762 2024-04-19 12:22:28.241 2024-04-19 12:24:47.881              2024-04-19
# 763 2024-04-19 12:25:03.246 2024-04-19 12:27:28.694              2024-04-19
# 767 2024-04-19 12:52:11.809 2024-04-19 12:54:42.503              2024-04-19
#
# ...

# %%
len(df[df['Specific needs categories'].astype(str).str.contains("Family unity")])
# Out:
# 177

# %%
df[df['Specific needs categories'].astype(str).str.contains("Family unity")]
# Out:
#                       start                     end Date of Data Collection  \
# 5   2024-04-15 09:05:28.639 2024-04-15 12:35:17.629              2024-04-15
# 7   2024-04-15 10:55:23.364 2024-04-15 12:36:34.591              2024-04-15
# 13  2024-04-15 13:35:54.774 2024-04-15 13:46:06.176              2024-04-15
# 17  2024-04-15 10:02:15.578 2024-04-15 10:10:30.854              2024-04-15
# 24  2024-04-15 11:23:49.920 2024-04-15 11:28:05.273              2024-04-15
# ..                      ...                     ...                     ...
# 755 2024-04-19 11:49:09.608 2024-04-19 11:51:23.287              2024-04-19
# 758 2024-04-19 12:04:05.729 2024-04-19 12:06:24.524              2024-04-19
# 762 2024-04-19 12:22:28.241 2024-04-19 12:24:47.881              2024-04-19
# 763 2024-04-19 12:25:03.246 2024-04-19 12:27:28.694              2024-04-19
# 767 2024-04-19 12:52:11.809 2024-04-19 12:54:42.503              2024-04-19
#
# ...

# %%
water=df[df['Does your family have access to water?']=='YES']
len(water)
# Out:
# 611

# %%
shelter=df[df['Does your family have a shelter ?']=='YES']
len(shelter)
# Out:
# 518

# %%
healthcare=df[df['Does your family have easy access to healthcare?']=='YES']
len(healthcare)
# Out:
# 585
